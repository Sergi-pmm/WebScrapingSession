# %% [markdown]
# # 00 — Comprobación del entorno
#
# Este notebook sirve para comprobar que el entorno de trabajo está correctamente configurado.
#
# **Objetivos:**
# - Verificar la versión de Python
# - Confirmar qué intérprete se está usando
# - Comprobar el sistema operativo
# - Asegurarse de que el entorno conda está activo

# %% [markdown]
# ## 1. Versión de Python
#
# Ejecuta la siguiente celda para ver la versión exacta de Python.

# %%
import sys
print(sys.version)
# Out:
# 3.13.11 | packaged by Anaconda, Inc. | (main, Dec 10 2025, 21:21:08) [Clang 20.1.8 ]

# %% [markdown]
# ## 2. Intérprete de Python en uso
#
# La ruta debe apuntar al entorno creado con **Miniconda**.

# %%
print(sys.executable)
# Out:
# /opt/miniconda3/bin/python

# %% [markdown]
# ## 3. Sistema operativo
#
# Información básica del sistema donde se está ejecutando el notebook.

# %%
import platform
print(platform.platform())
# Out:
# macOS-26.2-arm64-arm-64bit-Mach-O

# %% [markdown]
# ## 4. Comprobación de librerías básicas
#
# Si esta celda no produce errores, el entorno está listo para empezar.

# %%
import math
import json
import datetime

print("Librerías básicas importadas correctamente")
# Out:
# Librerías básicas importadas correctamente

# %% [markdown]
# ## Conclusión
#
# Si todas las celdas anteriores se han ejecutado sin errores, el entorno está correctamente configurado
# y puedes continuar con la sesión.
